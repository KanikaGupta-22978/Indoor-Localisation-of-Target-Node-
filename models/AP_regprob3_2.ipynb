# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\data_2\data.csv")
df.tail(50)
# Out:
#       AP1  location_AP1_X  location_AP1_y  AP2  location_AP2_X  \
# 1510  -73               0               7  -68               0
# 1511  -74               0               7  -69               0
# 1512  -73               0               7  -68               0
# 1513  -74               0               7  -69               0
# 1514  -73               0               7  -70               0
# 1515  -72               0               7  -71               0
# 1516  -72               0               7  -72               0
# 1517  -74               0               7  -70               0
# 1518  -72               0               7  -73               0
# 1519  -76               0               7  -71               0
# 1520  -73               0               7  -70               0
# 1521  -71               0               7  -71               0
# 1522  -72               0               7  -69               0
# 1523  -71               0               7  -69               0
# ...

# %%
df.shape, df.size
# Out:
# ((1560, 16), 24960)

# %%
df.dtypes
# Out:
# AP1                         int64
# location_AP1_X              int64
# location_AP1_y              int64
# AP2                         int64
# location_AP2_X              int64
# location_AP2_y              int64
# AP3                         int64
# location_AP3_X              int64
# location_AP3_y              int64
# AP4                         int64
# location_AP4_X              int64
# location_AP4_y              int64
# target_node_facing_to      object
# angle_of_target_node        int64
# target_X                  float64
# target_y                  float64
# dtype: object

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
np.random.seed(42)
X=df.drop(["target_X", "target_y"], axis=1)
# Convert categorical variable into dummy/indicator variables
X = pd.get_dummies(df.drop(["target_X", "target_y"], axis=1))

y=df[["target_X", "target_y"]]
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2)
model=RandomForestRegressor(n_estimators=100)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.8956902325174279

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
# Evaluate the model
y_preds = model.predict(X_test)
print("Regressor model on the test set")
print(f"r2:{r2_score(y_test, y_preds)*100:2f}%")
print(f"mae:{mean_absolute_error(y_test, y_preds)*100:2f}%")
print(f"mse:{mean_squared_error(y_test, y_preds)*100:2f}%")
# Out:
# Regressor model on the test set
# r2:89.569023%
# mae:38.614503%
# mse:53.386363%

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Assuming you have the following input data
input_data = [
    [ 1558,	-70,	0,	7,	-74,	0,	0,	-67,	9,	0,	-68,	7,	9,	west,	180,	5.4,	5.6]
]

# Convert the input data into a pandas DataFrame
input_df = pd.DataFrame(input_data, columns=['AP1', 'location_AP1_X', 'location_AP1_y', 'AP2', 'location_AP2_X', 'location_AP2_y',
                                            'AP3', 'location_AP3_X', 'location_AP3_y', 'AP4', 'location_AP4_X', 'location_AP4_y',
                                            'target_node', 'target_node_facing_to', 'angle_of_target_node', 'target_X', 'target_y'])

# Encode the categorical variable
label_encoder = LabelEncoder()
input_df['target_node_facing_to'] = label_encoder.fit_transform(input_df['target_node_facing_to'])

# Split the data into training and testing sets
X_train = input_df.drop(['target_X', 'target_y'], axis=1)
y_train = input_df[['target_X', 'target_y']]

# Train the RandomForestRegressor model
model = RandomForestRegressor()
model.fit(X_train, y_train)

# Make predictions using the trained model
y_pred = model.predict(X_train)

# Print the predicted target_X and target_y values
print("Predicted target_X:", y_pred[:, 0])
print("Predicted target_y:", y_pred[:, 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 8
#       4 from sklearn.preprocessing import LabelEncoder
#       6 # Assuming you have the following input data
#       7 input_data = [
# ----> 8     [ 1558,	-70,	0,	7,	-74,	0,	0,	-67,	9,	0,	-68,	7,	9,	west,	180,	5.4,	5.6]
#       9 ]
#      11 # Convert the input data into a pandas DataFrame
#      12 input_df = pd.DataFrame(input_data, columns=['AP1', 'location_AP1_X', 'location_AP1_y', 'AP2', 'location_AP2_X', 'location_AP2_y',
#      13                                             'AP3', 'location_AP3_X', 'location_AP3_y', 'AP4', 'location_AP4_X', 'location_AP4_y',
#      14                                             'target_node', 'target_node_facing_to', 'angle_of_target_node', 'target_X', 'target_y'])
#
# NameError: name 'west' is not defined

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Assuming you have the following input data
input_data = [
    [1558, -70, 0, 7, -74, 0, 0, -67, 9, 0, -68, 7, 9, 'west', 180, 5.4, 5.6]
]

# Convert the input data into a pandas DataFrame
input_df = pd.DataFrame(input_data, columns=['AP1', 'location_AP1_X', 'location_AP1_y', 'AP2', 'location_AP2_X', 'location_AP2_y',
                                            'AP3', 'location_AP3_X', 'location_AP3_y', 'AP4', 'location_AP4_X', 'location_AP4_y',
                                            'target_node', 'target_node_facing_to', 'angle_of_target_node', 'target_X', 'target_y'])

# Encode the categorical variable
label_encoder = LabelEncoder()
input_df['target_node_facing_to'] = label_encoder.fit_transform(input_df['target_node_facing_to'])

# Split the data into training and testing sets
X_train = input_df.drop(['target_X', 'target_y'], axis=1)
y_train = input_df[['target_X', 'target_y']]

# Train the RandomForestRegressor model
model = RandomForestRegressor()
model.fit(X_train, y_train)

# Make predictions using the trained model
y_pred = model.predict(X_train)

# Print the predicted target_X and target_y values
print("Predicted target_X:", y_pred[:, 0])
print("Predicted target_y:", y_pred[:, 1])
