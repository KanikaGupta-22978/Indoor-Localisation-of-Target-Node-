# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\data_2\data.csv")
df
# Out:
#       AP1  location_AP1_X  location_AP1_y  AP2  location_AP2_X  \
# 0     -68               0               7  -54               0
# 1     -63               0               7  -53               0
# 2     -66               0               7  -53               0
# 3     -65               0               7  -55               0
# 4     -68               0               7  -53               0
# ...   ...             ...             ...  ...             ...
# 1555  -70               0               7  -73               0
# 1556  -70               0               7  -73               0
# 1557  -68               0               7  -73               0
# 1558  -70               0               7  -74               0
# 1559  -70               0               7  -73               0
#
#       location_AP2_y  AP3  location_AP3_X  location_AP3_y  AP4  \
# 0                  0  -82               9               0  -66
# 1                  0  -79               9               0  -65
# 2                  0  -82               9               0  -64
# 3                  0  -81               9               0  -66
# 4                  0  -78               9               0  -67
# ...              ...  ...             ...             ...  ...
# 1555               0  -67               9               0  -67
# 1556               0  -67               9               0  -68
# 1557               0  -68               9               0  -67
# 1558               0  -67               9               0  -68
# 1559               0  -69               9               0  -68
#
#       location_AP4_X  location_AP4_y target_node_facing_to   \
# 0                  7               9                 north
# 1                  7               9                 north
# 2                  7               9                 north
# 3                  7               9                 north
# 4                  7               9                 north
# ...              ...             ...                    ...
# 1555               7               9                   west
# 1556               7               9                   west
# 1557               7               9                   west
# 1558               7               9                   west
# 1559               7               9                   west
#
#       angle_of_target_node   target_X  target_y
# 0                        90       1.8       0.0
# 1                        90       1.8       0.0
# 2                        90       1.8       0.0
# 3                        90       1.8       0.0
# 4                        90       1.8       0.0
# ...                     ...       ...       ...
# 1555                    180       5.4       5.6
# 1556                    180       5.4       5.6
# 1557                    180       5.4       5.6
# 1558                    180       5.4       5.6
# 1559                    180       5.4       5.6
#
# [1560 rows x 16 columns]

# %%
df.shape, df.size
# Out:
# ((1560, 16), 24960)

# %%
df.dtypes
# Out:
# AP1                         int64
# location_AP1_X              int64
# location_AP1_y              int64
# AP2                         int64
# location_AP2_X              int64
# location_AP2_y              int64
# AP3                         int64
# location_AP3_X              int64
# location_AP3_y              int64
# AP4                         int64
# location_AP4_X              int64
# location_AP4_y              int64
# target_node_facing_to      object
# angle_of_target_node        int64
# target_X                  float64
# target_y                  float64
# dtype: object

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
np.random.seed(42)
X=df.drop(["target_X", "target_y"], axis=1)
# Convert categorical variable into dummy/indicator variables
X = pd.get_dummies(df.drop(["target_X", "target_y"], axis=1))

y=df[["target_X", "target_y"]]
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2)
model=RandomForestRegressor(n_estimators=100)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.8956902325174279

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
# Evaluate the model
y_preds = model.predict(X_test)
print("Regressor model on the test set")
print(f"r2:{r2_score(y_test, y_preds)*100:2f}%")
print(f"mae:{mean_absolute_error(y_test, y_preds)*100:2f}%")
print(f"mse:{mean_squared_error(y_test, y_preds)*100:2f}%")
# Out:
# Regressor model on the test set
# r2:89.569023%
# mae:38.614503%
# mse:53.386363%
