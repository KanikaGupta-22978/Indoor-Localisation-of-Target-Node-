# %%
import pandas as pd
df1=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\1.csv")
df2=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\2.csv")
df3=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\3.csv")
df4=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\4.csv")
df5=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\5.csv")
df6=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\6.csv")
df7=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\7.csv")
df8=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\8.csv")
df9=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\9.csv")
df10=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\10.csv")
df11=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\11.csv")
df12=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\12.csv")
df13=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\13.csv")
df14=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\14.csv")
df15=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\15.csv")
df16=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\16.csv")
df17=pd.read_csv(r"C:\Users\ftska\all projects\sample_project_2\Mini_Project\data\17.csv")
combined_df=pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17], ignore_index=True)
combined_df
# Out:
#      AP1  angle_AP1 location_AP1  AP2  angle_AP2 location_AP2  AP3   \
# 0    -45      44.25    (9.6,7.5)  -34       0.00        (0,0)   -40
# 1    -40      44.25    (9.6,7.5)  -38       0.00        (0,0)   -39
# 2    -40      44.25    (9.6,7.5)  -39       0.00        (0,0)   -40
# 3    -40      44.25    (9.6,7.5)  -35       0.00        (0,0)   -39
# 4    -40      44.25    (9.6,7.5)  -35       0.00        (0,0)   -39
# ..   ...        ...          ...  ...        ...          ...   ...
# 846  -26      75.96    (9.6,7.5)  -47      35.41        (0,0)   -49
# 847  -26      75.96    (9.6,7.5)  -48      35.41        (0,0)   -49
# 848  -25      75.96    (9.6,7.5)  -47      35.41        (0,0)   -49
# 849  -25      75.96    (9.6,7.5)  -49      35.41        (0,0)   -49
# 850  -24      75.96    (9.6,7.5)  -47      35.41        (0,0)   -46
#
#      angle_AP3 location_AP3  Unnamed: 9 cordinates of targeted  node
# 0        78.83      (0,7.5)         NaN                       (1.5,0)
# ...

# %%
combined_df = combined_df.loc[:, ~combined_df.columns.str.contains('^Unnamed')]
combined_df
# Out:
#      AP1  angle_AP1 location_AP1  AP2  angle_AP2 location_AP2  AP3   \
# 0    -45      44.25    (9.6,7.5)  -34       0.00        (0,0)   -40
# 1    -40      44.25    (9.6,7.5)  -38       0.00        (0,0)   -39
# 2    -40      44.25    (9.6,7.5)  -39       0.00        (0,0)   -40
# 3    -40      44.25    (9.6,7.5)  -35       0.00        (0,0)   -39
# 4    -40      44.25    (9.6,7.5)  -35       0.00        (0,0)   -39
# ..   ...        ...          ...  ...        ...          ...   ...
# 846  -26      75.96    (9.6,7.5)  -47      35.41        (0,0)   -49
# 847  -26      75.96    (9.6,7.5)  -48      35.41        (0,0)   -49
# 848  -25      75.96    (9.6,7.5)  -47      35.41        (0,0)   -49
# 849  -25      75.96    (9.6,7.5)  -49      35.41        (0,0)   -49
# 850  -24      75.96    (9.6,7.5)  -47      35.41        (0,0)   -46
#
#      angle_AP3 location_AP3 cordinates of targeted  node
# 0        78.83      (0,7.5)                       (1.5,0)
# ...

# %%
combined_df=combined_df.loc[:,~combined_df.columns.str.contains('^label')]
combined_df
# Out:
#      AP1  angle_AP1 location_AP1  AP2  angle_AP2 location_AP2  AP3   \
# 0    -45      44.25    (9.6,7.5)  -34       0.00        (0,0)   -40
# 1    -40      44.25    (9.6,7.5)  -38       0.00        (0,0)   -39
# 2    -40      44.25    (9.6,7.5)  -39       0.00        (0,0)   -40
# 3    -40      44.25    (9.6,7.5)  -35       0.00        (0,0)   -39
# 4    -40      44.25    (9.6,7.5)  -35       0.00        (0,0)   -39
# ..   ...        ...          ...  ...        ...          ...   ...
# 846  -26      75.96    (9.6,7.5)  -47      35.41        (0,0)   -49
# 847  -26      75.96    (9.6,7.5)  -48      35.41        (0,0)   -49
# 848  -25      75.96    (9.6,7.5)  -47      35.41        (0,0)   -49
# 849  -25      75.96    (9.6,7.5)  -49      35.41        (0,0)   -49
# 850  -24      75.96    (9.6,7.5)  -47      35.41        (0,0)   -46
#
#      angle_AP3 location_AP3 cordinates of targeted  node
# 0        78.83      (0,7.5)                       (1.5,0)
# ...

# %%
combined_df.columns
# Out:
# Index(['AP1', 'angle_AP1', 'location_AP1', 'AP2', 'angle_AP2', 'location_AP2',
#        'AP3 ', 'angle_AP3', 'location_AP3', 'cordinates of targeted  node '],
#       dtype='object')

# %%
combined_df.columns = ['AP1', 'angle_AP1', 'location_AP1', 'AP2', 'angle_AP2', 'location_AP2', 'AP3', 'angle_AP3', 'location_AP3' ,'target']
combined_df.head(55)
# Out:
#     AP1  angle_AP1 location_AP1  AP2  angle_AP2 location_AP2  AP3  angle_AP3  \
# 0   -45      44.25    (9.6,7.5)  -34        0.0        (0,0)  -40      78.83
# 1   -40      44.25    (9.6,7.5)  -38        0.0        (0,0)  -39      78.83
# 2   -40      44.25    (9.6,7.5)  -39        0.0        (0,0)  -40      78.83
# 3   -40      44.25    (9.6,7.5)  -35        0.0        (0,0)  -39      78.83
# 4   -40      44.25    (9.6,7.5)  -35        0.0        (0,0)  -39      78.83
# 5   -40      44.25    (9.6,7.5)  -38        0.0        (0,0)  -40      78.83
# 6   -41      44.25    (9.6,7.5)  -38        0.0        (0,0)  -40      78.83
# 7   -40      44.25    (9.6,7.5)  -37        0.0        (0,0)  -39      78.83
# 8   -40      44.25    (9.6,7.5)  -39        0.0        (0,0)  -39      78.83
# 9   -41      44.25    (9.6,7.5)  -37        0.0        (0,0)  -40      78.83
# 10  -41      44.25    (9.6,7.5)  -38        0.0        (0,0)  -41      78.83
# ...

# %%
combined_df.dtypes
# Out:
# AP1               int64
# angle_AP1       float64
# location_AP1     object
# AP2               int64
# angle_AP2       float64
# location_AP2     object
# AP3               int64
# angle_AP3       float64
# location_AP3     object
# target           object
# dtype: object
